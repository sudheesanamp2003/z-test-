# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tabulate as tabulate
import seaborn as sns

# %%
df=pd.read_csv('/content/dev1.csv')

# %%
df1=df.head(100)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05-01-2006  2006      5       12016     GUM        5      13162    MAJ
# 1   05-01-2003  2003      5       10299     ANC        1      13856    OKO
# 2   03-01-2007  2007      3       10721     BOS       13      12651    KEF
# 3   12-01-2004  2004     12       11259     DAL       74      16271    YYZ
# 4   05-01-2009  2009      5       13303     MIA       33      11075    CMW
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 95  09-01-2005  2005      9       11540     ELP       74      16078    YHM
# 96  12-01-2001  2001     12       12892     LAX       91      13252    MEX
# 97  07-01-2002  2002      7       13891     ONT       91      13594    MZT
# 98  08-01-2009  2009      8       13667     NGU       38      13618    NBW
# 99  06-01-2009  2009      6       15045     SUU       91      13856    OKO
#
# ...

# %%
df1.describe()
# Out:
#              Year       Month    usg_apt_id     usg_wac     fg_apt_id  \
# count   100.00000  100.000000    100.000000  100.000000    100.000000
# mean   2005.50000    5.840000  13072.110000   42.240000  13579.730000
# std       2.65718    3.498109   1417.514868   25.174189   1878.552967
# min    2001.00000    1.000000  10299.000000    1.000000  10371.000000
# 25%    2003.75000    3.000000  12016.000000   22.000000  11914.500000
# 50%    2005.00000    5.500000  13221.000000   33.500000  13556.000000
# 75%    2008.00000    9.000000  13954.250000   64.000000  15174.000000
# max    2010.00000   12.000000  16091.000000   93.000000  16334.000000
#
#            fg_wac     airlineid  carriergroup  Scheduled     Charter  \
# count  100.000000    100.000000     100.00000      100.0  100.000000
# mean   460.240000  20241.400000       0.79000        0.0    8.070000
# std    298.348421    339.791766       0.40936        0.0   15.993215
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       98 non-null     object
#  11  carriergroup  100 non-null    int64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    int64
#  14  Charter       100 non-null    int64
#  15  Total         100 non-null    int64
# dtypes: int64(11), object(5)
# memory usage: 12.6+ KB

# %%
df1.shape
# Out:
# (100, 16)

# %%
df1.nunique()
# Out:
# data_dte        64
# Year            10
# Month           12
# usg_apt_id      49
# usg_apt         49
# usg_wac         28
# fg_apt_id       66
# fg_apt          66
# fg_wac          32
# airlineid       48
# carrier         49
# carriergroup     2
# type             1
# Scheduled        1
# Charter         23
# Total           23
# dtype: int64

# %%
df1.isna().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         2
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
s=df1['carrier'].mean

# %%
df1.fillna(s)
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05-01-2006  2006      5       12016     GUM        5      13162    MAJ
# 1   05-01-2003  2003      5       10299     ANC        1      13856    OKO
# 2   03-01-2007  2007      3       10721     BOS       13      12651    KEF
# 3   12-01-2004  2004     12       11259     DAL       74      16271    YYZ
# 4   05-01-2009  2009      5       13303     MIA       33      11075    CMW
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 95  09-01-2005  2005      9       11540     ELP       74      16078    YHM
# 96  12-01-2001  2001     12       12892     LAX       91      13252    MEX
# 97  07-01-2002  2002      7       13891     ONT       91      13594    MZT
# 98  08-01-2009  2009      8       13667     NGU       38      13618    NBW
# 99  06-01-2009  2009      6       15045     SUU       91      13856    OKO
#
# ...

# %%
df1.plot.area()

# %%
r=df1.Year

# %%
e=df1.Month

# %%
plt.bar(r,e)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.xlabel("Year")
plt.ylabel("Month")
plt.title("passenger report")
plt.bar(r,e)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.hist(r,color='blue')
# Out:
# (array([ 9.,  5., 11., 15., 11., 10., 13.,  8., 12.,  6.]),
#  array([2001. , 2001.9, 2002.8, 2003.7, 2004.6, 2005.5, 2006.4, 2007.3,
#         2008.2, 2009.1, 2010. ]),
#  <a list of 10 Patch objects>)

# %%
sns.displot(r,bins=100)

# %% [markdown]
# We use a displot (also known as a distribution plot) to represent data in histogram form. It is a univariant set of collected data, which means the data distribution of one variable will be shown against another variable. In Python, we use the Seaborn library with Matplotlib for data visualization.

# %% [markdown]
# bins denotes the width of the line

# %%
sns.heatmap(df1.corr())

# %% [markdown]
# corr=corrilation, explains how one or more variables are related to each other

# %%
df1.plot.box(vert=False)

# %%
x=df1.usg_wac
plt.pie(x)
plt.show()

# %%
plt.polar(x)
plt.show()
